# %%
import requests, json
from tqdm import tqdm
from bs4 import BeautifulSoup
import urllib.parse as parse
import pandas as pd

# %%
def articlesAdrsLstGen(keywords):
  adrs_lst = []

  for page in tqdm(range(1, 5002, 10)):
    try:
      if len(adrs_lst) == 2000:
        break
      else:
        headers = {
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36',
        }
        url = 'https://search.naver.com/search.naver?'
        qs = 'where=news&sm=tab_pge&query=러시아%20한국%20경제&sort=1&photo=0&field=0&pd=3&ds=2018.02.24&de=2019.04.15&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20180224to20190415,a:all&start=1'
        params = dict(parse.parse_qsl(qs))
        params['cluster_rank'] = ''
        params['query'] = keywords
        params['start'] = page
        resp = requests.get(url, headers=headers, params=params)
        soup = BeautifulSoup(resp.content, 'lxml')
        adrs = soup.select('div.news_info > div.info_group > a')
        for item in adrs:
          if len(adrs_lst) == 2000:
            break
          elif 'https://news.naver.com/main/read.naver?' in item['href'] and item['href'] not in adrs_lst:
            adrs_lst.append(item['href'])
    except Exception as e:
      print()
      print(e)
      print(item['href'])
      continue
  return adrs_lst

# 'div.news_wrap.api_ani_send > div > div.news_info > div.info_group > a
# '#sp_nws45 > div.news_wrap.api_ani_send > div > div.news_info > div.info_group > a:nth-child(3)'
# '#sp_nws50 > div > div > div.news_info > div.info_group > a:nth-child(3)'

def articlesTableGen(adrs_lst):
  articles = {
    '등록일시': [],
    '제목': [],
    '내용': [],
    '주소': [],
  }

  for adrs in tqdm(adrs_lst):
    if len(articles['제목']) == 1456:
      break
    else:
      try:
        headers = {
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36',
        }
        url = adrs
        resp = requests.get(url, headers=headers)
        soup = BeautifulSoup(resp.content, 'lxml')
        get_title = soup.select('#articleTitle')
        get_time = soup.select('#main_content > div.article_header > div.article_info > div > span.t11')
        get_content = soup.select('#articleBodyContents')
        articles['등록일시'].append(get_time[0].text)
        articles['제목'].append(get_title[0].text)
        articles['내용'].append(get_content[0].text)
        articles['주소'].append(adrs)
      except Exception as e:
        print()
        print(e)
        print('오류주소', adrs)
        continue
  table = pd.DataFrame(articles)
  return table

# %%
lst = articlesAdrsLstGen('러시아 한국 경제')
# Out:
#  66%|██████▌   | 331/501 [06:08<03:09,  1.11s/it]

# %%
len(lst)
# Out:
# 2000

# %%
len(set(lst))
# Out:
# 2000

# %%
df = articlesTableGen(lst)
# Out:
#   2%|▏         | 35/2000 [00:23<32:02,  1.02it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000757599
#   2%|▏         | 40/2000 [00:28<31:11,  1.05it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000756932
#   2%|▏         | 42/2000 [00:30<32:19,  1.01it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000756742
#   2%|▏         | 43/2000 [00:31<36:00,  1.10s/it]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000756600
#   2%|▏         | 44/2000 [00:32<38:44,  1.19s/it]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000756599
#   3%|▎         | 68/2000 [00:48<27:14,  1.18it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=468&aid=0000489670
#   4%|▍         | 90/2000 [01:03<30:52,  1.03it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000751783
#   5%|▌         | 105/2000 [01:13<25:23,  1.24it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000751492
#   5%|▌         | 106/2000 [01:14<30:34,  1.03it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000751185
#   8%|▊         | 155/2000 [01:49<28:20,  1.09it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0
/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000687147
#  62%|██████▏   | 1248/2000 [14:02<12:05,  1.04it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000686637
#  67%|██████▋   | 1344/2000 [15:00<09:38,  1.13it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000684756
#  70%|██████▉   | 1395/2000 [15:29<07:57,  1.27it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=015&aid=0004013786
#  70%|███████   | 1409/2000 [15:38<08:36,  1.14it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=015&aid=0004013523
#  72%|███████▎  | 1450/2000 [16:03<07:40,  1.19it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000682337
#  74%|███████▍  | 1490/2000 [16:25<06:59,  1.21it/s]
# list index out of range
# 오류주소 https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=215&aid=0000681468
#  76%|███████▌  | 1512/2000 [16:38<05:22,  1.51it/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   등록일시    1456 non-null   object
#  1   제목      1456 non-null   object
#  2   내용      1456 non-null   object
#  3   주소      1456 non-null   object
# dtypes: object(4)
# memory usage: 45.6+ KB

# %%
df
# Out:
#                       등록일시                                       제목  \
# 0      2019.04.15. 오후 8:54                 [정운찬 칼럼]우리가 세워야 할 새로운 나라
# 1      2019.04.15. 오후 4:26        "자본 빨아들이는 북미 셰일가스…좋은 투자 기회 생겨날 것"
# 2     2019.04.15. 오전 11:45  "중앙아시아 중심 카자흐스탄, 기계, 인프라, 서비스 경제 협력 유망"
# 3      2019.04.15. 오전 9:13     [김대성의 환율이야기] 노르웨이 국부펀드가 한국 채권 배제한 교훈
# 4      2019.04.15. 오전 9:03           베네수엘라·아르헨·그리스…나랏 돈 펑펑 쓰다 경제 파탄
# ...                    ...                                      ...
# 1451   2018.09.12. 오전 1:06           푸틴 "美·北 관계 정상화는 한반도 평화에 매우 중요"
# 1452   2018.09.11. 오후 9:34      러시아 루블화, 2년 반만에 최고기록…미-중 '무역전쟁' 여파?
# 1453   2018.09.11. 오후 6:10               HMR 해외 전략은… 현지 생산·현지 기업 인수
# 1454   2018.09.11. 오후 6:05         이동걸 산업은행 회장 "남북경협에 국제금융기구도 참여해야"
# 1455   2018.09.11. 오후 5:55                       시베리아횡단 열차 탄 이낙연 총리
#
#                                                      내용  \
# 0     \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 1     \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 2     \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 3     \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 4     \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# ...                                                 ...
# 1451  \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 1452  \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 1453  \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 1454  \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
# 1455  \n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction...
#
#                                                      주소
# 0     https://news.naver.com/main/read.naver?mode=LS...
# 1     https://news.naver.com/main/read.naver?mode=LS...
# 2     https://news.naver.com/main/read.naver?mode=LS...
# 3     https://news.naver.com/main/read.naver?mode=LS...
# 4     https://news.naver.com/main/read.naver?mode=LS...
# ...                                                 ...
# 1451  https://news.naver.com/main/read.naver?mode=LS...
# 1452  https://news.naver.com/main/read.naver?mode=LS...
# 1453  https://news.naver.com/main/read.naver?mode=LS...
# 1454  https://news.naver.com/main/read.naver?mode=LS...
# 1455  https://news.naver.com/main/read.naver?mode=LS...
#
# [1456 rows x 4 columns]

# %%
cond = df.duplicated()
df[cond].count()
# Out:
# 등록일시    0
# 제목      0
# 내용      0
# 주소      0
# dtype: int64

# %%
df.to_csv('러시아 한국 경제_v2_2019041520180911.csv', index=False)
