# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('독립일지_일상.csv', index_col=[0])

# %%
df 

# 장르별로 파쳐 값의 드러나는 특성이 다를까 
# 요일별로 다를까?
# 어떤 장르의 독자들이 댓글참여가 적극적인가 
# 평점 준사람과 댓글을 준 사람의 비중 
# 대체 누가 댓글을 다는가?
# 평점참여자 대비 댓글수로 추측해볼 수 있느 ㄴ것들
# 평점을 스케일링 해서 > 전체 회차 평점의 평균을 내서 회차별 평점에 빼는 식으로
# 평점은 대부분 좋다 > 스케일링해서 생각해볼 필요가 있다
# 함께 고민하며 작업들을 리스트업 한 후에 분업화
# 평점기여자 수가 유지되는데 평점이 떨어지는가 아닌가
# 회차별 평점기여자수 - 평점기여자수 전체의 평균

# 생각 방향
# 스케일링 해서 생각하기 > 평균값을 활용해서


# 평점이 확 떨어진 후 회복한 경우 전후와 떨어졌을 때를 나눠서 생각해보면 그 자체로도 발견할 수 있는 게 있을 것 같고 장르별로 차이가 있을 것 같다.

# 장르 / 제목 / 회차 칼럼 추가 > 맨 앞에 붙이기
# 제목은 띄어쓰기 없이
# 회차는 숫자만
# 그 다음 csv 파일 1개로 합치기
# Out:
#        좋아요수    평점  평점기여자수  전체댓글수   베댓공감수  베댓비공감수
# 0    100204  9.95   58100  12648  314596     980
# 1     90299  9.96   44390   9703  495372    2077
# 2     74552  9.96   38880   5818  407763    1491
# 3     73272  9.97   38328   5330  337369    1037
# 4     70637  9.97   38481   5016  314033     950
# ..      ...   ...     ...    ...     ...     ...
# 159   28841  9.96   17402   1588   98294     539
# 160   29463  9.98   17751   1693   91389     160
# 161   29253  9.97   17631   2326  116681     248
# 162   26669  9.97   15923   2581  102099     252
# 163   21943  9.97   13740   1409   63738     286
#
# [164 rows x 6 columns]

# %%
sns.lineplot(data=df['평점기여자수'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
