# %%
import pandas as pd

# %%
df = pd.read_csv('네이버웹툰장르통합.csv')

# %%
df[df['장르'] == '일상']['제목'].unique()
# Out:
# array(['결혼생활그림일기', '골방환상곡', '나는귀머거리다', '달콤한인생', '독립일지', '모두에게완자가',
#        '범이올시다', '윌유메리미', '자취로운생활', '혈액형에관한간단한고찰'], dtype=object)
