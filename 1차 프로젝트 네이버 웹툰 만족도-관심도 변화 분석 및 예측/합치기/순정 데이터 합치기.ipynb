# %%
import pandas as pd

# %%
df = pd.read_csv('순정.csv', index_col=[0])

# %%
df.index.name = ''
df.to_csv('순정.csv')

# %%
df = pd.read_csv('순정.csv', index_col=[0])
df
# Out:
#      장르          제목   회차   좋아요수    평점  평점기여자수  전체댓글수   베댓공감수  베댓비공감수
# 0    순정  오로지너를이기고싶어    1  39168  9.92   30175   2752  130534    2769
# 1    순정  오로지너를이기고싶어    2  29676  9.91   20413   1169   76951    1129
# 2    순정  오로지너를이기고싶어    3  26996  9.95   18351   1675  105134    3774
# 3    순정  오로지너를이기고싶어    4  25911  9.91   22849   1441  150744    4429
# 4    순정  오로지너를이기고싶어    5  24961  9.95   18205   1222  111796    1155
# ..   ..         ...  ...    ...   ...     ...    ...     ...     ...
# 179  순정    홍시는날좋아해!  180   7025  9.98    6903    211   35785      44
# 180  순정    홍시는날좋아해!  181   7128  9.98    7303    387   92536      94
# 181  순정    홍시는날좋아해!  182   7161  9.98    7149    267   52426     139
# 182  순정    홍시는날좋아해!  183   6023  9.99    5949    296   28211      43
# 183  순정    홍시는날좋아해!  184   5136  9.98    5341    178   15654     230
#
# [1446 rows x 9 columns]

# %%
# def addCols(fileName):
#   df = pd.read_csv(fileName, index_col=[0])
#   df.insert(0, '장르', fileName[-6:-4])
#   df.insert(1, '제목', fileName[:-7])
#   df.insert(2, '회차', [i for i in range(1, len(df)+1)])
#   return df

# %%
# df1 = addCols('결혼생활그림일기_일상.csv')
# df1.info()
# df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 0 to 108
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   장르      109 non-null    object
#  1   제목      109 non-null    object
#  2   회차      109 non-null    int64
#  3   좋아요수    109 non-null    int64
#  4   평점      109 non-null    float64
#  5   평점기여자수  109 non-null    int64
#  6   전체댓글수   109 non-null    int64
#  7   베댓공감수   109 non-null    int64
#  8   베댓비공감수  109 non-null    int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 8.5+ KB
#      장르        제목   회차   좋아요수    평점  평점기여자수  전체댓글수  베댓공감수  베댓비공감수
# 0    일상  결혼생활그림일기    1  15274  9.84   25871   1507  44769     960
# 1    일상  결혼생활그림일기    2  12651  9.75   20780   1208  39838     776
# 2    일상  결혼생활그림일기    3   9564  9.87   13535    753  25199     560
# 3    일상  결혼생활그림일기    4   8820  9.92   12078    615  29143     408
# 4    일상  결혼생활그림일기    5   8182  9.93   11313    658  26372     294
# ..   ..       ...  ...    ...   ...     ...    ...    ...     ...
# 104  일상  결혼생활그림일기  105   3831  9.98    5336    158   6615      29
# 105  일상  결혼생활그림일기  106   3419  9.98    4767    141  12002      47
# 106  일상  결혼생활그림일기  107   3488  9.97    5209    141  10131      67
# 107  일상  결혼생활그림일기  108   3255  9.98    4768    235  13034      31
# 108  일상  결혼생활그림일기  109   2695  9.98    4045    143  10034      20
#
# [109 rows x 9 columns]

# %%
fileNames = ['결혼생활그림일기_일상.csv',
'골방환상곡_일상.csv',
'나는귀머거리다_일상.csv',
'달콤한인생_일상.csv',
'독립일지_일상.csv',
'모두에게완자가_일상.csv',
'범이올시다_일상.csv',
'윌유메리미_일상.csv',
'자취로운생활_일상.csv',
'혈액형에관한간단한고찰_일상.csv',]

dfs= []

for fileName in fileNames:
  dfs.append(addCols(fileName))

# %%
dfs[9].tail()
# Out:
#      장르           제목   회차  좋아요수    평점  평점기여자수  전체댓글수   베댓공감수  베댓비공감수
# 221  일상  혈액형에관한간단한고찰  222  3584  9.94    8467   2442   36048    1527
# 222  일상  혈액형에관한간단한고찰  223  3411  9.90    8388   1600   64941    1598
# 223  일상  혈액형에관한간단한고찰  224  3481  9.94    8635   2063   63469    1824
# 224  일상  혈액형에관한간단한고찰  225  4259  9.94   10026   2289   70991    2415
# 225  일상  혈액형에관한간단한고찰  226  7269  9.93   20368   5420  137729    4214

# %%
new_df = pd.concat(dfs)

# %%
new_df.set_index(pd.Series(range(len(new_df))), inplace=True)

# %%
new_df
# Out:
#       장르           제목   회차   좋아요수    평점  평점기여자수  전체댓글수   베댓공감수  베댓비공감수
# 0     일상     결혼생활그림일기    1  15274  9.84   25871   1507   44769     960
# 1     일상     결혼생활그림일기    2  12651  9.75   20780   1208   39838     776
# 2     일상     결혼생활그림일기    3   9564  9.87   13535    753   25199     560
# 3     일상     결혼생활그림일기    4   8820  9.92   12078    615   29143     408
# 4     일상     결혼생활그림일기    5   8182  9.93   11313    658   26372     294
# ...   ..          ...  ...    ...   ...     ...    ...     ...     ...
# 2581  일상  혈액형에관한간단한고찰  222   3584  9.94    8467   2442   36048    1527
# 2582  일상  혈액형에관한간단한고찰  223   3411  9.90    8388   1600   64941    1598
# 2583  일상  혈액형에관한간단한고찰  224   3481  9.94    8635   2063   63469    1824
# 2584  일상  혈액형에관한간단한고찰  225   4259  9.94   10026   2289   70991    2415
# 2585  일상  혈액형에관한간단한고찰  226   7269  9.93   20368   5420  137729    4214
#
# [2586 rows x 9 columns]

# %%
new_df.to_csv('일상.csv', index=False)

# %%
pd.read_csv('일상.csv')
# Out:
#       장르           제목   회차   좋아요수    평점  평점기여자수  전체댓글수   베댓공감수  베댓비공감수
# 0     일상     결혼생활그림일기    1  15274  9.84   25871   1507   44769     960
# 1     일상     결혼생활그림일기    2  12651  9.75   20780   1208   39838     776
# 2     일상     결혼생활그림일기    3   9564  9.87   13535    753   25199     560
# 3     일상     결혼생활그림일기    4   8820  9.92   12078    615   29143     408
# 4     일상     결혼생활그림일기    5   8182  9.93   11313    658   26372     294
# ...   ..          ...  ...    ...   ...     ...    ...     ...     ...
# 2581  일상  혈액형에관한간단한고찰  222   3584  9.94    8467   2442   36048    1527
# 2582  일상  혈액형에관한간단한고찰  223   3411  9.90    8388   1600   64941    1598
# 2583  일상  혈액형에관한간단한고찰  224   3481  9.94    8635   2063   63469    1824
# 2584  일상  혈액형에관한간단한고찰  225   4259  9.94   10026   2289   70991    2415
# 2585  일상  혈액형에관한간단한고찰  226   7269  9.93   20368   5420  137729    4214
#
# [2586 rows x 9 columns]
